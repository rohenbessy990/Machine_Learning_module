# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv(r"C:\Users\ROHEN\OneDrive\Desktop\documents\AI\supervised_learning\logistic_regression_multiclass\winequality.csv",sep=";")
#sep";" for ; seperated csv

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
corrDF=data.corr()
corrDF
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
corrColumns=abs(corrDF['quality']).sort_values(ascending=False)
corrColumns
# Out:
# quality                 1.000000
# alcohol                 0.435575
# density                 0.307123
# chlorides               0.209934
# volatile acidity        0.194723
# total sulfur dioxide    0.174737
# fixed acidity           0.113663
# pH                      0.099427
# residual sugar          0.097577
# sulphates               0.053678
# citric acid             0.009209
# free sulfur dioxide     0.008158
# Name: quality, dtype: float64

# %%
Finalcolumns=corrColumns[corrColumns>0.1].index
Finalcolumns
# Out:
# Index(['quality', 'alcohol', 'density', 'chlorides', 'volatile acidity',
#        'total sulfur dioxide', 'fixed acidity'],
#       dtype='object')

# %%
finalData = data[Finalcolumns]
finalData
# Out:
#       quality  alcohol  density  chlorides  volatile acidity  \
# 0           6      8.8  1.00100      0.045              0.27
# 1           6      9.5  0.99400      0.049              0.30
# 2           6     10.1  0.99510      0.050              0.28
# 3           6      9.9  0.99560      0.058              0.23
# 4           6      9.9  0.99560      0.058              0.23
# ...       ...      ...      ...        ...               ...
# 4893        6     11.2  0.99114      0.039              0.21
# 4894        5      9.6  0.99490      0.047              0.32
# 4895        6      9.4  0.99254      0.041              0.24
# 4896        7     12.8  0.98869      0.022              0.29
# 4897        6     11.8  0.98941      0.020              0.21
#
#       total sulfur dioxide  fixed acidity
# 0                    170.0            7.0
# 1                    132.0            6.3
# 2                     97.0            8.1
# 3                    186.0            7.2
# ...

# %%
X = finalData.drop(["quality"],axis=1)
X
# Out:
#       alcohol  density  chlorides  volatile acidity  total sulfur dioxide  \
# 0         8.8  1.00100      0.045              0.27                 170.0
# 1         9.5  0.99400      0.049              0.30                 132.0
# 2        10.1  0.99510      0.050              0.28                  97.0
# 3         9.9  0.99560      0.058              0.23                 186.0
# 4         9.9  0.99560      0.058              0.23                 186.0
# ...       ...      ...        ...               ...                   ...
# 4893     11.2  0.99114      0.039              0.21                  92.0
# 4894      9.6  0.99490      0.047              0.32                 168.0
# 4895      9.4  0.99254      0.041              0.24                 111.0
# 4896     12.8  0.98869      0.022              0.29                 110.0
# 4897     11.8  0.98941      0.020              0.21                  98.0
#
#       fixed acidity
# 0               7.0
# 1               6.3
# ...

# %%
y = finalData["quality"]
pd.DataFrame(y)
# Out:
#       quality
# 0           6
# 1           6
# 2           6
# 3           6
# 4           6
# ...       ...
# 4893        6
# 4894        5
# 4895        6
# 4896        7
# 4897        6
#
# [4898 rows x 1 columns]

# %%
y.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=50)

# %%
# X_train.head()

# %%
# X_test.head()

# %%
# y_train.head()

# %%
# y_test.head()

# %%
# sc = StandardScaler()
# X_train=pd.DataFrame(sc.fit_transform(X_train),columns=X_train.columns)
# X_test=pd.DataFrame(sc.transform(X_test),columns=X_test.columns)

# %%
# model=LogisticRegression()

# %%
# model.fit(X_train,y_train)

# %%
# model.predict(X_test)

# %%
# model.score(X_train,y_train)

# %%
# model.score(X_test,y_test)

# %%
from sklearn.tree import DecisionTreeClassifier
df_classifier = DecisionTreeClassifier(criterion="entropy",max_depth=3)    #changing from gini to entropy
df_classifier.fit(X_train,y_train)
y_pred = df_classifier.predict(X_test)
trainAccuracy = df_classifier.score(X_train,y_train)
testAccuracy =df_classifier.score(X_test,y_test)
print(f"Train Accuarcy : {trainAccuracy}")
print(f"Test Accuarcy : {testAccuracy}")
# from sklearn.tree import plot_tree
# plt.figure(figsize=(15,10))
# plot_tree(df_classifier,filled=True)
# Out:
# Train Accuarcy : 0.5186697782963827
# Test Accuarcy : 0.5312925170068027
